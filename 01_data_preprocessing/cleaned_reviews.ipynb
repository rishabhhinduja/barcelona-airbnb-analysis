# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\Airbnb Project\reviews.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992991 entries, 0 to 992990
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     992991 non-null  int64
#  1   id             992991 non-null  int64
#  2   date           992991 non-null  object
#  3   reviewer_id    992991 non-null  int64
#  4   reviewer_name  992987 non-null  object
#  5   comments       992887 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 45.5+ MB

# %%
df=df.drop(columns=['reviewer_name','comments'])

# %%
df['date']=pd.to_datetime(df['date'],errors='coerce')

# %%
df.to_csv(r"D:\Airbnb Project\fact_reviews_clean.csv", index=False)
