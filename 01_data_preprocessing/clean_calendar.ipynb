# %%
import pandas as pd

# %%
df=pd.read_csv("D:\Airbnb Project\calendar.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\rishabh hinduja\AppData\Local\Temp\ipykernel_24368\2697070944.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df=pd.read_csv("D:\Airbnb Project\calendar.csv")

# %%
df
# Out:
#          listing_id        date available  minimum_nights  maximum_nights
# 0           1069572  2026-03-22         f               3            1125
# 1           1069572  2026-03-23         t               3            1125
# 2           1069572  2026-03-24         t               3            1125
# 3           1069572  2026-03-25         t               3            1125
# 4           1069572  2026-03-26         t               3            1125
# ...             ...         ...       ...             ...             ...
# 5879055     2180003  2027-03-17         t               3             150
# 5879056     2180003  2027-03-18         t               3             150
# 5879057     2180003  2027-03-19         t               3             150
# 5879058     2180003  2027-03-20         t               3             150
# 5879059     2180003  2027-03-21         t               3             150
#
# [5879060 rows x 5 columns]

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#          listing_id        date available  minimum_nights  maximum_nights
# 0           1069572  2026-03-22         f               3            1125
# 1           1069572  2026-03-23         t               3            1125
# 2           1069572  2026-03-24         t               3            1125
# 3           1069572  2026-03-25         t               3            1125
# 4           1069572  2026-03-26         t               3            1125
# ...             ...         ...       ...             ...             ...
# 5879055     2180003  2027-03-17         t               3             150
# 5879056     2180003  2027-03-18         t               3             150
# 5879057     2180003  2027-03-19         t               3             150
# 5879058     2180003  2027-03-20         t               3             150
# 5879059     2180003  2027-03-21         t               3             150
#
# [5879060 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5879060 entries, 0 to 5879059
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   minimum_nights  int64
#  4   maximum_nights  int64
# dtypes: int64(3), object(2)
# memory usage: 224.3+ MB

# %%
df.head(500)
# Out:
#      listing_id        date available  minimum_nights  maximum_nights
# 0       1069572  2026-03-22         f               3            1125
# 1       1069572  2026-03-23         t               3            1125
# 2       1069572  2026-03-24         t               3            1125
# 3       1069572  2026-03-25         t               3            1125
# 4       1069572  2026-03-26         t               3            1125
# 5       1069572  2026-03-27         f               3            1125
# 6       1069572  2026-03-28         f               3            1125
# 7       1069572  2026-03-29         f               3            1125
# 8       1069572  2026-03-30         f               3            1125
# 9       1069572  2026-03-31         f               3            1125
# 10      1069572  2026-04-01         f               3            1125
# 11      1069572  2026-04-02         f               3            1125
# ...

# %%
pd.set_option('display.max.rows',500)

# %%
df
# Out:
#                   date available  minimum_nights  maximum_nights
# listing_id
# 1069572     2026-03-22         f               3            1125
# 1069572     2026-03-23         t               3            1125
# 1069572     2026-03-24         t               3            1125
# 1069572     2026-03-25         t               3            1125
# 1069572     2026-03-26         t               3            1125
# ...                ...       ...             ...             ...
# 2180003     2027-03-17         t               3             150
# 2180003     2027-03-18         t               3             150
# 2180003     2027-03-19         t               3             150
# 2180003     2027-03-20         t               3             150
# 2180003     2027-03-21         t               3             150
#
# [5879060 rows x 4 columns]

# %%
df[df['listing_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [listing_id, date, available, minimum_nights, maximum_nights]
# Index: []

# %%
df['date']=pd.to_datetime(df['date'],format='%dd%mm%yyyy')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5879060 entries, 0 to 5879059
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            datetime64[ns]
#  2   available       string
#  3   minimum_nights  int64
#  4   maximum_nights  int64
# dtypes: datetime64[ns](1), int64(3), string(1)
# memory usage: 224.3 MB

# %%
df['available']=df['available'].astype('string')

# %%
df.to_csv(r"D:\Airbnb Project\calendar_cleaned.csv", index=False)
